# %% [markdown]
# ## Importamos librerías

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Hacemos predicciones

# %%
model_path = './flor_model90.h5py'
model = tf.keras.models.load_model(model_path)

# Lista de nombres de las clases
class_labels = ["astilbe", "bellflower", "iris", "rose", "Rudbeckia_hirta"]

# Definir las imágenes de las flores y sus nombres
flowers = ["bell.jpg", "iris.jpg", "rosa.jpg", "astilbe.jpg", "Rudbeckia.jpg"]

# Definir el tamaño objetivo para las imágenes de entrada del modelo
target_size = (32, 32)

# Predecir y graficar cada imagen de flor
plt.figure(figsize=(15, 8))

for i, flower in enumerate(flowers, start=1):
    # Cargar la imagen y redimensionarla
    img = image.load_img(flower, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Realizar la predicción
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    predicted_label = class_labels[predicted_class_index]

    # Mostrar la imagen y la predicción
    plt.subplot(1, 5, i)
    plt.imshow(img)
    plt.title(f'Prediction: {predicted_label}')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step
